# %% [markdown]
# <a href="https://colab.research.google.com/github/ak2742/mlplay/blob/apps/fooocus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 14.3 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6354, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (290/290), done.
# remote: Total 6354 (delta 184), reused 245 (delta 96), pack-reused 5951
# Receiving objects: 100% (6354/6354), 33.21 MiB | 27.78 MiB/s, done.
# Resolving deltas: 100% (3555/3555), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.4.3
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
